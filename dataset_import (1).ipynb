# %%
import pandas as pd
df = pd.read_csv('/home/student/dataset.csv')
df
# Out:
#      Course   Enrollment No.       Name M/F Date of Birth Permanent City  \
# 0  Imsc(IT)  201901619010121     Udity    F      26/08/02      Ahmedabad
# 1  Imsc(IT)  201901619010122     Rishav   M      05/03/98      Ahmedabad
# 2       MBA  201901619010123   Kanishka   F      09/01/00      Ahmedabad
# 3       BBA  201901619010124    Aastha    F      18/03/02      Ahmedabad
# 4       BSC  201901619010125  Ruchanshu   M      11/12/02      Ahmedabad
# 5    B.Tech  201901619010126    Pinkesh   M      16/07/02      Ahmedabad
# 6     B.com  201901619010127      Parth   M      16/04/02      Ahmedabad
# 7     M.com  201901619010128     Dhruvi   F      29/08/02      Ahmedabad
# 8     PGDCA  201901619010129    Trushil   M      19/07/02      Ahmedabad
#
#    Mobile No.             Email ID  SSC(%)  HSC(%)  Graduation    Degree  \
# 0  2657894025      udity@gmail.com  87.00%  85.00%        2022  Imsc(IT)
# 1  4589789630     rishav@gmail.com  88.00%  86.00%        2022  Imsc(IT)
# ...

# %%
len(df)
# Out:
# 9

# %%
df.head(2)
# Out:
#      Course   Enrollment No.    Name M/F Date of Birth Permanent City  \
# 0  Imsc(IT)  201901619010121  Udity    F      26/08/02      Ahmedabad
# 1  Imsc(IT)  201901619010122  Rishav   M      05/03/98      Ahmedabad
#
#    Mobile No.          Email ID  SSC(%)  HSC(%)  Graduation    Degree  \
# 0  2657894025   udity@gmail.com  87.00%  85.00%        2022  Imsc(IT)
# 1  4589789630  rishav@gmail.com  88.00%  86.00%        2022  Imsc(IT)
#
#        University PG Avg. Till now
# 0  GLS University           89.00%
# 1  GLS University           90.00%

# %%
df.tail(2)
# Out:
#   Course   Enrollment No.     Name M/F Date of Birth Permanent City  \
# 7  M.com  201901619010128   Dhruvi   F      29/08/02      Ahmedabad
# 8  PGDCA  201901619010129  Trushil   M      19/07/02      Ahmedabad
#
#    Mobile No.           Email ID  SSC(%)  HSC(%)  Graduation Degree  \
# 7  4589789636   dhruvi@gmail.com  94.00%  92.00%        2019  M.com
# 8  4589789637  trushil@gmail.com  95.00%  93.00%        2021  PGDCA
#
#        University PG Avg. Till now
# 7  GLS University           96.00%
# 8  GLS University           97.00%

# %%
df.query('Graduation > 90').head(2)
# Out:
#      Course   Enrollment No.    Name M/F Date of Birth Permanent City  \
# 0  Imsc(IT)  201901619010121  Udity    F      26/08/02      Ahmedabad
# 1  Imsc(IT)  201901619010122  Rishav   M      05/03/98      Ahmedabad
#
#    Mobile No.          Email ID  SSC(%)  HSC(%)  Graduation    Degree  \
# 0  2657894025   udity@gmail.com  87.00%  85.00%        2022  Imsc(IT)
# 1  4589789630  rishav@gmail.com  88.00%  86.00%        2022  Imsc(IT)
#
#        University PG Avg. Till now
# 0  GLS University           89.00%
# 1  GLS University           90.00%

# %%
df.query('Graduation > 2020')
# Out:
#      Course   Enrollment No.       Name M/F Date of Birth Permanent City  \
# 0  Imsc(IT)  201901619010121     Udity    F      26/08/02      Ahmedabad
# 1  Imsc(IT)  201901619010122     Rishav   M      05/03/98      Ahmedabad
# 2       MBA  201901619010123   Kanishka   F      09/01/00      Ahmedabad
# 3       BBA  201901619010124    Aastha    F      18/03/02      Ahmedabad
# 4       BSC  201901619010125  Ruchanshu   M      11/12/02      Ahmedabad
# 5    B.Tech  201901619010126    Pinkesh   M      16/07/02      Ahmedabad
# 8     PGDCA  201901619010129    Trushil   M      19/07/02      Ahmedabad
#
#    Mobile No.             Email ID  SSC(%)  HSC(%)  Graduation    Degree  \
# 0  2657894025      udity@gmail.com  87.00%  85.00%        2022  Imsc(IT)
# 1  4589789630     rishav@gmail.com  88.00%  86.00%        2022  Imsc(IT)
# 2  4589789631   kanishka@gmail.com  89.00%  87.00%        2022       MBA
# 3  4589789632     aastha@gmail.com  90.00%  88.00%        2021       BBA
# ...
